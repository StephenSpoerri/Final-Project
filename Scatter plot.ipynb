# %%
# source  https://sda.berkeley.edu/sdaweb/analysis/?dataset=scfcomb
#AGE	Age of head of household
#INCOME	Total amount of income of household, 2016 dollars

# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
df = pd.read_csv('sub-data.csv')
df.head()

x = 'AGE'
y = 'INCOME'

plt.scatter(x = df[x], y = df[y])
plt.xlabel('age')
plt.ylabel('amount of income')
plt.title('       Amount earned by age of the head of the household')
# Out:
# Text(0.5, 1.0, '       Amount earned by age of the head of the household')

# %%
#
df = pd.read_csv('sub-data2.csv')
df.head()

x = 'AGE'
y = 'OTHFIN'

plt.scatter(x = df[x], y = df[y])
plt.xlabel('AGE')
plt.ylabel('Total value of financial assets')
plt.title('age by total financial assets')
# Out:
# Text(0.5, 1.0, 'age by total financial assets')

# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
df = pd.read_csv('sub-data3.csv')
df.head()

x = 'AGE'
y = 'NOWN'

plt.scatter(x = df[x], y = df[y])
plt.xlabel('age')
plt.ylabel('Total number of owned vehicles')
plt.title('age by total number of owned vehicles')
# Out:
# Text(0.5, 1.0, 'age by total number of owned vehicles')

# %%
df = pd.read_csv('sub-data4.csv')
df.head()

x = 'AGE'
y = 'KGINC'

plt.scatter(x = df[x], y = df[y])
plt.xlabel('age')
plt.ylabel('Capital gains')
plt.title('age by capital gains')
# Out:
# Text(0.5, 1.0, 'age by capital gains')

# %%
import numpy as np
import statsmodels.api as sm
df5 = pd.read_csv('sub-data5.csv')
df5.head()

x = 'AGE'
y = 'NETWORTH'

plt.scatter(x = df5[x], y = df5[y])
plt.xlabel('age')
plt.ylabel('Networth')
plt.title('age by networth')
# Out:
# Text(0.5, 1.0, 'age by networth')

# %%
x_ary = df['AGE']
x_with_cnst = sm.add_constant(x_ary)
model = sm.OLS(df5['NETWORTH'], x_with_cnst)
results = model.fit()
b,m = results.params
print(m)
print(b)
# Out:
# 394484.2587480395
# -10725006.737169717

# %%
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:               NETWORTH   R-squared:                       0.016
# Model:                            OLS   Adj. R-squared:                  0.016
# Method:                 Least Squares   F-statistic:                     3896.
# Date:                Mon, 11 Jul 2022   Prob (F-statistic):               0.00
# Time:                        13:39:52   Log-Likelihood:            -4.5742e+06
# No. Observations:              238880   AIC:                         9.148e+06
# Df Residuals:                  238878   BIC:                         9.148e+06
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -1.073e+07   3.38e+05    -31.730      0.000   -1.14e+07   -1.01e+07
# ...

# %%
plt.figure(figsize = (20,10))
plt.scatter(df5['AGE'],df5['NETWORTH'])
plt.plot(x_ary, m*x_ary+b, color = 'red', linewidth = 5)
